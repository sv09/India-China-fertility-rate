# %%
import pandas as pd
import numpy as np

# %%
full_data = pd.read_csv("./WPP2022_Fertility_by_Age5.csv")
# Out:
# /Users/shreyavinodh/Library/Python/3.8/lib/python/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (2,3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
full_data.head()
# Out:
#    SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0          1    900   NaN       NaN       NaN        1.0          1
# 1          1    900   NaN       NaN       NaN        1.0          1
# 2          1    900   NaN       NaN       NaN        1.0          1
# 3          1    900   NaN       NaN       NaN        1.0          1
# 4          1    900   NaN       NaN       NaN        1.0          1
#
#   LocTypeName  ParentID Location  VarID Variant  Time  MidPeriod AgeGrp  \
# 0       World         0    World      2  Medium  1950     1950.5  10-14
# 1       World         0    World      2  Medium  1950     1950.5  15-19
# 2       World         0    World      2  Medium  1950     1950.5  20-24
# 3       World         0    World      2  Medium  1950     1950.5  25-29
# 4       World         0    World      2  Medium  1950     1950.5  30-34
#
#    AgeGrpStart  AgeGrpSpan     ASFR   PASFR     Births
# 0           10           5    4.539   0.467    571.496
# ...

# %%
full_data.shape
# Out:
# (2008395, 20)

# %%
India_China_data = full_data[(full_data["Variant"] == "Medium") & (full_data["Location"] == "India") | (full_data["Location"] == "China")]

# %%
India_China_data
# Out:
#         SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 662418         99    156   5.0       CHN        CN      156.0          4
# 662419         99    156   5.0       CHN        CN      156.0          4
# 662420         99    156   5.0       CHN        CN      156.0          4
# 662421         99    156   5.0       CHN        CN      156.0          4
# 662422         99    156   5.0       CHN        CN      156.0          4
# ...           ...    ...   ...       ...       ...        ...        ...
# 748336        111    356   NaN       IND        IN      356.0          4
# 748337        111    356   NaN       IND        IN      356.0          4
# 748338        111    356   NaN       IND        IN      356.0          4
# 748339        111    356   NaN       IND        IN      356.0          4
# 748340        111    356   NaN       IND        IN      356.0          4
#
#          LocTypeName  ParentID Location  VarID Variant  Time  MidPeriod  \
# ...

# %%
India_China_data.reset_index(inplace=True, drop=True)

# %%
India_China_data
# Out:
#       SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0            99    156   5.0       CHN        CN      156.0          4
# 1            99    156   5.0       CHN        CN      156.0          4
# 2            99    156   5.0       CHN        CN      156.0          4
# 3            99    156   5.0       CHN        CN      156.0          4
# 4            99    156   5.0       CHN        CN      156.0          4
# ...         ...    ...   ...       ...       ...        ...        ...
# 8401        111    356   NaN       IND        IN      356.0          4
# 8402        111    356   NaN       IND        IN      356.0          4
# 8403        111    356   NaN       IND        IN      356.0          4
# 8404        111    356   NaN       IND        IN      356.0          4
# 8405        111    356   NaN       IND        IN      356.0          4
#
#        LocTypeName  ParentID Location  VarID Variant  Time  MidPeriod AgeGrp  \
# ...

# %%
India_China_data = India_China_data[["Location", "Variant", "Time", "AgeGrp", "ASFR"]]

# %%
India_China_data
# Out:
#      Location Variant  Time AgeGrp     ASFR
# 0       China  Medium  1950  10-14    1.439
# 1       China  Medium  1950  15-19   83.816
# 2       China  Medium  1950  20-24  265.994
# 3       China  Medium  1950  25-29  273.484
# 4       China  Medium  1950  30-34  229.202
# ...       ...     ...   ...    ...      ...
# 8401    India  Medium  2100  30-34  116.699
# 8402    India  Medium  2100  35-39   53.957
# 8403    India  Medium  2100  40-44   11.719
# 8404    India  Medium  2100  45-49    1.445
# 8405    India  Medium  2100  50-54    0.067
#
# [8406 rows x 5 columns]

# %%
India_China_data.to_csv("India_China_data.csv", index=False)
